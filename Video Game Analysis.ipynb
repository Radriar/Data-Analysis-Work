# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Khada Jhin\Downloads\archive(4)\video_games_sales.csv")

# %%
df
# Out:
#         rank                                              name platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          year         genre   publisher  na_sales  eu_sales  jp_sales  \
# ...

# %%
rank = df.copy()
rank.set_index('rank', inplace = True);

# %%
rank.head(10)
# Out:
#                            name platform    year         genre publisher  \
# rank
# 1                    Wii Sports      Wii  2006.0        Sports  Nintendo
# 2             Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 3                Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 4             Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 5      Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 6                        Tetris       GB  1989.0        Puzzle  Nintendo
# 7         New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 8                      Wii Play      Wii  2006.0          Misc  Nintendo
# 9     New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 10                    Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#       na_sales  eu_sales  jp_sales  other_sales  global_sales
# rank
# 1        41.49     29.02      3.77         8.46         82.74
# ...

# %%
wii_df = df[df['platform'] == 'Wii']

wii_df
# Out:
#         rank                                               name platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# ...      ...                                                ...      ...
# 16517  16520                       Teenage Mutant Ninja Turtles      Wii
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16581  16584                                          Fit & Fun      Wii
#
#          year     genre                     publisher  na_sales  eu_sales  \
# ...

# %%
df['year'] = df['year'].replace([np.nan, np.inf, -np.inf], 0)
#noticed the year was not an INT data type. Later found out it was in a format unfamiliar and had to search it up.

# %%
df['year'] = df['year'].astype(int)
#after finding out the solution, converted the year column into an INT data type.

# %%
df.head()
# Out:
#    rank                      name platform  year         genre publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    na_sales  eu_sales  jp_sales  other_sales  global_sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
null_counts = df.isnull().sum()
null_counts
#checking for nulls
# Out:
# rank             0
# name             0
# platform         0
# year             0
# genre            0
# publisher       58
# na_sales         0
# eu_sales         0
# jp_sales         0
# other_sales      0
# global_sales     0
# dtype: int64

# %%
rows_with_nulls = df[df.isnull().any(axis=1)]
rows_with_nulls
# Out:
#         rank                                               name platform  \
# 470      471                         wwe Smackdown vs. Raw 2006      PS2
# 1303    1305                                     Triple Play 99       PS
# 1662    1664       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA
# 2222    2224                                 Bentley's Hackpack      GBA
# 3159    3161  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 3166    3168  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 3766    3768  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 4145    4147                                 Sonic the Hedgehog      PS3
# 4526    4528  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 4635    4637  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 5302    5304      Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)      Wii
# 5647    5649  Cartoon Network Collection: Game Boy Advance V...      GBA
# ...

# %%
df['publisher_missing'] = df['publisher'].isnull()
#Added a new column indicating whether the publisher was missing

# %%
df['publisher'] = df['publisher'].fillna('Unknown Publisher')
#with rows that did have a publisher missing, decided to replace or fill it in place with "Unknown Publisher"

# %%
df
# Out:
#         rank                                              name platform  year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...

# %%
df = df.set_index('rank')

# %%
df
# Out:
#                                                    name platform  year  \
# rank
# 1                                            Wii Sports      Wii  2006
# 2                                     Super Mario Bros.      NES  1985
# 3                                        Mario Kart Wii      Wii  2008
# 4                                     Wii Sports Resort      Wii  2009
# 5                              Pokemon Red/Pokemon Blue       GB  1996
# ...                                                 ...      ...   ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16597                     Men in Black II: Alien Escape       GC  2003
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16599                                        Know How 2       DS  2010
# 16600                                  Spirits & Spells      GBA  2003
#
#               genre   publisher  na_sales  eu_sales  jp_sales  other_sales  \
# rank
# ...

# %% [markdown]
# # Average Sales By Genre + Visualization

# %%
avg_sales_by_genre = df.groupby('genre')['global_sales'].mean()

sorted_avg_sales_by_genre = avg_sales_by_genre.sort_values(ascending=False)

sorted_avg_sales_by_genre 

#the sales are in millions for clarification.
# Out:
# genre
# Platform        0.938341
# Shooter         0.791885
# Role-Playing    0.623233
# Racing          0.586101
# Sports          0.567319
# Fighting        0.529375
# Action          0.528100
# Misc            0.465762
# Simulation      0.452364
# Puzzle          0.420876
# Strategy        0.257151
# Adventure       0.185879
# Name: global_sales, dtype: float64

# %%
sorted_avg_sales_by_genre 

plt.figure(figsize=(15, 6))
sns.barplot(x=sorted_avg_sales_by_genre.index, y=sorted_avg_sales_by_genre.values)
plt.title('Average Sales by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Sales (in millions)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Sales by Platform + Visualization

# %%
total_sales_by_platform = df.groupby('platform')['global_sales'].sum()
total_sales_by_platform
# Out:
# platform
# 2600      97.08
# 3DO        0.10
# 3DS      247.46
# DC        15.97
# DS       822.49
# GB       255.45
# GBA      318.50
# GC       199.36
# GEN       28.36
# GG         0.04
# N64      218.88
# NES      251.07
# NG         1.44
# PC       258.82
# PCFX       0.03
# PS       730.66
# PS2     1255.64
# PS3      957.84
# PS4      278.10
# PSP      296.28
# PSV       61.93
# SAT       33.59
# SCD        1.87
# SNES     200.05
# TG16       0.16
# WS         1.42
# Wii      926.71
# WiiU      81.86
# X360     979.96
# XB       258.26
# XOne     141.06
# Name: global_sales, dtype: float64

# %%
sorted_total_sales_by_platform = total_sales_by_platform.sort_values(ascending=False)

sorted_total_sales_by_platform
# Out:
# platform
# PS2     1255.64
# X360     979.96
# PS3      957.84
# Wii      926.71
# DS       822.49
# PS       730.66
# GBA      318.50
# PSP      296.28
# PS4      278.10
# PC       258.82
# XB       258.26
# GB       255.45
# NES      251.07
# 3DS      247.46
# N64      218.88
# SNES     200.05
# GC       199.36
# XOne     141.06
# 2600      97.08
# WiiU      81.86
# PSV       61.93
# SAT       33.59
# GEN       28.36
# DC        15.97
# SCD        1.87
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: global_sales, dtype: float64

# %%
sorted_total_sales_by_platform

plt.figure(figsize=(10, 6))
sns.barplot(x=sorted_total_sales_by_platform.index, y=sorted_total_sales_by_platform.values)
plt.title('Total Sales by Platform')
plt.xlabel('Platform')
plt.ylabel('Total Sales (in millions)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Most Popular Platform Based on the Sales, Platform, and Year

# %%
df.drop(df[df['year'] == 0].index, inplace=True)
#noticed that there was a year of 0. Should not be possible. Decided to delete any rows that had a year of 0.

# %%
sum_sales_by_platform_year = df.groupby(['platform', 'year'])['global_sales'].sum().reset_index()

# %%
sorted_sum_sales_by_platform_year = sum_sales_by_platform_year.sort_values(by='global_sales',ascending=False)
sorted_sum_sales_by_platform_year
# Out:
#     platform  year  global_sales
# 136      PS2  2004        211.78
# 204      Wii  2009        210.44
# 134      PS2  2002        205.40
# 135      PS2  2003        184.29
# 203      Wii  2008        174.16
# ..       ...   ...           ...
# 10       3DO  1994          0.02
# 23        DC  2007          0.02
# 36        DS  2014          0.02
# 178      PSV  2017          0.02
# 25        DS  1985          0.02
#
# [241 rows x 3 columns]

# %%
sorted_sum_sales_by_platform_year = sum_sales_by_platform_year.sort_values(by='global_sales',ascending=False)

# Plot
plt.figure(figsize=(10, 8))
sns.barplot(
    x='global_sales', 
    y='platform', 
    hue='year', 
    data=sorted_sum_sales_by_platform_year,
    palette='viridis'
)
plt.title('Total Sales by Platform and Year')
plt.xlabel('Total Sales')
plt.ylabel('Platform')
plt.legend(title='Year')
plt.show()
# Out:
# C:\Users\Khada Jhin\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
genre_sales_by_platform = df.groupby(['platform', 'genre'])['global_sales'].sum().reset_index()


top_genre_by_platform = genre_sales_by_platform.loc[genre_sales_by_platform.groupby('platform')['global_sales'].idxmax()]


platform_sales = df.groupby('platform')['global_sales'].sum().reset_index().sort_values(by='global_sales', ascending=False)


top_genre_by_platform_sorted = top_genre_by_platform.set_index('platform').loc[platform_sales['platform']].reset_index()


print(top_genre_by_platform_sorted)


plt.figure(figsize=(12, 8))
sns.barplot(
    data=top_genre_by_platform_sorted,
    x='global_sales',
    y='platform',
    hue='genre',
    dodge=False
)
plt.title('Top Genres by Platform (Sorted by Popularity)')
plt.xlabel('Total Global Sales (in millions)')
plt.ylabel('Platform')
plt.legend(title='Genre')
plt.show()
# Out:
#    platform         genre  global_sales
# 0       PS2        Sports        273.41
# 1      X360       Shooter        278.55
# 2       PS3        Action        307.88
# 3       Wii        Sports        292.06
# 4        DS          Misc        137.76
# 5        PS        Action        127.05
# 6       GBA      Platform         78.30
# 7       PSP        Action         64.72
# 8       PS4        Action         87.06
# 9        PC    Simulation         51.91
# 10       XB       Shooter         63.55
# 11       GB  Role-Playing         88.24
# 12      NES      Platform         95.78
# 13      3DS  Role-Playing         75.74
# 14      N64        Racing         40.09
# 15     SNES      Platform         65.65
# 16       GC        Action         37.84
# 17     XOne       Shooter         51.61
# 18     2600        Action         29.34
# 19     WiiU      Platform         21.24
# 20      PSV        Action         20.01
# 21      SAT      Fighting          8.52
# ...

# %% [markdown]
# # Sales by the Year

# %%
# Sales by year
sales_by_year = df.groupby('year')['global_sales'].sum()
sales_by_year
# Out:
# year
# 1980     11.38
# 1981     35.77
# 1982     28.86
# 1983     16.79
# 1984     50.36
# 1985     53.94
# 1986     37.07
# 1987     21.74
# 1988     47.22
# 1989     73.45
# 1990     49.39
# 1991     32.23
# 1992     76.16
# 1993     45.98
# 1994     79.17
# 1995     88.11
# 1996    199.15
# 1997    200.98
# 1998    256.47
# 1999    251.27
# 2000    201.56
# 2001    331.47
# 2002    395.52
# 2003    357.85
# 2004    419.31
# 2005    459.94
# 2006    521.04
# 2007    611.13
# 2008    678.90
# 2009    667.30
# 2010    600.45
# 2011    515.99
# 2012    363.54
# 2013    368.11
# 2014    337.05
# 2015    264.44
# 2016     70.93
# 2017      0.05
# 2020      0.29
# Name: global_sales, dtype: float64

# %%
sorted_sales_by_year = sales_by_year.sort_values(ascending=False)
sorted_sales_by_year
# Out:
# year
# 2008    678.90
# 2009    667.30
# 2007    611.13
# 2010    600.45
# 2006    521.04
# 2011    515.99
# 2005    459.94
# 2004    419.31
# 2002    395.52
# 2013    368.11
# 2012    363.54
# 2003    357.85
# 2014    337.05
# 2001    331.47
# 2015    264.44
# 1998    256.47
# 1999    251.27
# 2000    201.56
# 1997    200.98
# 1996    199.15
# 1995     88.11
# 1994     79.17
# 1992     76.16
# 1989     73.45
# 2016     70.93
# 1985     53.94
# 1984     50.36
# 1990     49.39
# 1988     47.22
# 1993     45.98
# 1986     37.07
# 1981     35.77
# 1991     32.23
# 1982     28.86
# 1987     21.74
# 1983     16.79
# 1980     11.38
# 2020      0.29
# 2017      0.05
# Name: global_sales, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=sales_by_year.index, y=sales_by_year.values, marker='o')
plt.title('Sales Over the Years')
plt.xlabel('Year')
plt.ylabel('Total Sales (in millions)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Distribution of Sales Among Publishers

# %%
sales_distribution_by_publisher = df.groupby('publisher')['global_sales'].sum()

# Calculate total sales
total_sales = sales_distribution_by_publisher.sum()

# Define the threshold for displaying top publishers
threshold = 0.05  # e.g., top 5% of total sales
min_sales = total_sales * threshold

# Filter publishers by the threshold
top_publishers = sales_distribution_by_publisher[sales_distribution_by_publisher >= min_sales]
other_publishers = sales_distribution_by_publisher[sales_distribution_by_publisher < min_sales]

# Combine 'Other' publishers
top_publishers = top_publishers.append(pd.Series({'Other (a collective of many publishers)': other_publishers.sum()}))
# Out:
# C:\Users\Khada Jhin\AppData\Local\Temp\ipykernel_12032\2981266127.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_publishers = top_publishers.append(pd.Series({'Other (a collective of many publishers)': other_publishers.sum()}))

# %%
plt.figure(figsize=(10, 6))
top_publishers.plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Sales Among Publishers')
plt.ylabel('')  # Remove the y-label for better visualization
plt.show()

# %% [markdown]
# # Genre Trends by Year

# %%
genre_trends = df.groupby(['year', 'genre']).size().unstack().fillna(0)

# %%
plt.figure(figsize=(14, 8))
genre_trends.plot(kind='area', stacked=True, alpha=0.5, figsize=(14, 8))
plt.title('Trends in Game Genres Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Games')
plt.xticks(rotation=45)
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
genre_trends_reset = genre_trends.reset_index()
genre_trends_melted = genre_trends_reset.melt(id_vars='year', var_name='genre', value_name='number_of_games')

g = sns.FacetGrid(genre_trends_melted, col='genre', col_wrap=4, sharex=True, sharey=True)
g.map_dataframe(sns.lineplot, x='year', y='number_of_games', marker='o')
g.set_titles(col_template='{col_name}')
g.set_axis_labels('Year', 'Number of Games')
g.add_legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Game with the Highest Sales

# %%
highest_sales_game = df.loc[df['global_sales'].idxmax()]
highest_sales_game
# Out:
# name                 Wii Sports
# platform                    Wii
# year                       2006
# genre                    Sports
# publisher              Nintendo
# na_sales                  41.49
# eu_sales                  29.02
# jp_sales                   3.77
# other_sales                8.46
# global_sales              82.74
# publisher_missing         False
# Name: 1, dtype: object

# %% [markdown]
# # Games Published Each Year

# %%
games_per_year = df.groupby('year').size()
print(games_per_year)
# Out:
# year
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      41
# 1992      43
# 1993      60
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1998     379
# 1999     338
# 2000     349
# 2001     482
# 2002     829
# 2003     775
# 2004     763
# 2005     941
# 2006    1008
# 2007    1202
# 2008    1428
# 2009    1431
# 2010    1259
# 2011    1139
# 2012     657
# 2013     546
# 2014     582
# 2015     614
# 2016     344
# 2017       3
# 2020       1
# dtype: int64

# %% [markdown]
# # The data for 2017-2020 is quite strange. Certainly there were games released between those periods and more games that have been published than we are given but I'm not certain. I pulled this data from a dataset so this is what we have to go off of.

# %% [markdown]
# # Average Sales Per Game Per Publisher

# %%
avg_sales_per_publisher = df.groupby('publisher')['global_sales'].mean()
avg_sales_per_publisher_sorted = avg_sales_per_publisher.sort_values(ascending=False)
avg_sales_per_publisher_sorted
# Out:
# publisher
# Palcom                        4.170000
# Red Orb                       2.620000
# Nintendo                      2.563836
# Arena Entertainment           2.360000
# UEP Systems                   2.250000
#                                 ...
# Boost On                      0.010000
# Genterprise                   0.010000
# Rain Games                    0.010000
# Interworks Unlimited, Inc.    0.010000
# Interchannel-Holon            0.010000
# Name: global_sales, Length: 577, dtype: float64

# %% [markdown]
# # Outliers?

# %%
sales_summary = df['global_sales'].describe()
print(sales_summary)
# Out:
# count    16327.000000
# mean         0.540232
# std          1.565732
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.480000
# max         82.740000
# Name: global_sales, dtype: float64

# %%
plt.figure(figsize=(12, 6))

# Histogram
plt.subplot(1, 2, 1)
sns.histplot(df['global_sales'], kde=True)
plt.title('Distribution of Sales')

# Box Plot
plt.subplot(1, 2, 2)
sns.boxplot(x=df['global_sales'])
plt.title('Box Plot of Sales')

plt.tight_layout()
plt.show()

# %%
Q1 = sales_summary['25%']
Q3 = sales_summary['75%']
IQR = Q3 - Q1

# Identify outliers
outliers = df[df['global_sales'] > (Q3 + 1.5 * IQR)]
print("\nOutliers:")
outliers
# Out:
# Outliers:
#                              name platform  year         genre  \
# rank
# 1                      Wii Sports      Wii  2006        Sports
# 2               Super Mario Bros.      NES  1985      Platform
# 3                  Mario Kart Wii      Wii  2008        Racing
# 4               Wii Sports Resort      Wii  2009        Sports
# 5        Pokemon Red/Pokemon Blue       GB  1996  Role-Playing
# ...                           ...      ...   ...           ...
# 1844    Need for Speed: ProStreet      Wii  2007        Racing
# 1845                     Pikmin 3     WiiU  2013      Strategy
# 1846               Legend of Mana       PS  1999  Role-Playing
# 1847       Lumines: Puzzle Fusion      PSP  2004        Puzzle
# 1848  Toy Story 3: The Video Game      PS3  2010        Action
#
#                        publisher  na_sales  eu_sales  jp_sales  other_sales  \
# rank
# 1                       Nintendo     41.49     29.02      3.77         8.46
# ...

# %% [markdown]
# # Seems that Nintendo's "Wii Sports" is the big outlier. Kind of surprising and not surprising at the same time. The game has grown remarkable fame for its unique and fun gameplay as well internet 'meme' culture.

# %% [markdown]
# # Popular Genres by Each Region and Popular Games by Each Region

# %%
genre_sales_by_region = df.groupby('genre')[['na_sales', 'eu_sales', 'jp_sales', 'global_sales']].sum()

# Find the most popular genre in each region
most_popular_genre_na = genre_sales_by_region['na_sales'].idxmax()
most_popular_genre_eu = genre_sales_by_region['eu_sales'].idxmax()
most_popular_genre_jp = genre_sales_by_region['jp_sales'].idxmax()
most_popular_genre_global = genre_sales_by_region ['global_sales'].idxmax()


print(f"Most popular genre in NA: {most_popular_genre_na}")
print(f"Most popular genre in EU: {most_popular_genre_eu}")
print(f"Most popular genre in JP: {most_popular_genre_jp}")

plt.figure(figsize=(12, 6))
genre_sales_by_region.plot(kind='bar')
plt.title('Total Sales by Genre in Different Regions')
plt.xlabel('Genre')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.legend(title='Region')
plt.tight_layout()
plt.show()
# Out:
# Most popular genre in NA: Action
# Most popular genre in EU: Action
# Most popular genre in JP: Role-Playing

# %%
game_sales_by_region = df.groupby('name')[['na_sales', 'eu_sales', 'jp_sales']].sum()

# Finding the most popular game in each region
most_popular_game_na = game_sales_by_region['na_sales'].idxmax()
most_popular_game_eu = game_sales_by_region['eu_sales'].idxmax()
most_popular_game_jp = game_sales_by_region['jp_sales'].idxmax()

print(f"Most popular game in NA: {most_popular_game_na}")
print(f"Most popular game in EU: {most_popular_game_eu}")
print(f"Most popular game in JP: {most_popular_game_jp}")


#cannot visualize this as it would take too much processing power and time and that there are massive amounts of game titles in this data set, which would make it look insanely messy.
# Out:
# Most popular game in NA: Wii Sports
# Most popular game in EU: Wii Sports
# Most popular game in JP: Pokemon Red/Pokemon Blue

# %% [markdown]
# # Popular Publishers by Each Region

# %%
publisher_sales = df.groupby('publisher')[['na_sales', 'eu_sales', 'jp_sales']].sum()

# Identify top publishers in each region
top_publishers_na = publisher_sales['na_sales'].nlargest(5)
top_publishers_eu = publisher_sales['eu_sales'].nlargest(5)
top_publishers_jp = publisher_sales['jp_sales'].nlargest(5)

print("Top Publishers in NA:")
print(top_publishers_na)

print("\nTop Publishers in EU:")
print(top_publishers_eu)

print("\nTop Publishers in JP:")
print(top_publishers_jp)

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# NA Sales
top_publishers_na.plot(kind='pie', ax=axes[0], autopct='%1.1f%%', legend=False, title='NA Sales')

# EU Sales
top_publishers_eu.plot(kind='pie', ax=axes[1], autopct='%1.1f%%', legend=False, title='EU Sales')

# JP Sales
top_publishers_jp.plot(kind='pie', ax=axes[2], autopct='%1.1f%%', legend=False, title='JP Sales')

plt.tight_layout()
plt.show()
# Out:
# Top Publishers in NA:
# publisher
# Nintendo                       816.87
# Electronic Arts                595.07
# Activision                     429.70
# Sony Computer Entertainment    265.22
# Ubisoft                        253.43
# Name: na_sales, dtype: float64
#
# Top Publishers in EU:
# publisher
# Nintendo                       418.74
# Electronic Arts                371.27
# Activision                     215.53
# Sony Computer Entertainment    187.72
# Ubisoft                        163.32
# Name: eu_sales, dtype: float64
#
# Top Publishers in JP:
# publisher
# Nintendo                        455.42
# Namco Bandai Games              127.07
# Konami Digital Entertainment     91.30
# Sony Computer Entertainment      74.10
# Capcom                           68.08
# Name: jp_sales, dtype: float64

# %%
df['global_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']

# Group by publisher and sum the sales for each region and globally
publisher_sales = df.groupby('publisher')[['na_sales', 'eu_sales', 'jp_sales', 'global_sales']].sum()

# Identify top publishers based on global sales
top_publishers_global = publisher_sales['global_sales'].nlargest(5)

print("Top Publishers by Global Sales:")
print(top_publishers_global)

# Filter the original publisher_sales DataFrame to include only the top publishers
top_publishers_sales = publisher_sales.loc[top_publishers_global.index]

# Convert the DataFrame to long format for seaborn
top_publishers_sales_long = top_publishers_sales.reset_index().melt(id_vars='publisher', var_name='Region', value_name='Sales')

# Visualize the top publishers with a grouped bar chart
plt.figure(figsize=(14, 8))
sns.barplot(x='publisher', y='Sales', hue='Region', data=top_publishers_sales_long, palette='viridis')
plt.title('Top Publishers by Global Sales')
plt.xlabel('Publisher')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.legend(title='Region')
plt.tight_layout()
plt.show()
# Out:
# Top Publishers by Global Sales:
# publisher
# Nintendo                       1786.36
# Electronic Arts                1110.15
# Activision                      727.11
# Sony Computer Entertainment     607.49
# Ubisoft                         474.51
# Name: global_sales, dtype: float64

# %%
sales_by_year_genre = df.groupby(['year', 'genre'])['global_sales'].sum().reset_index()

# Calculate the year-over-year growth rate
sales_by_year_genre['growth_rate'] = sales_by_year_genre.groupby('genre')['global_sales'].pct_change() * 100

print("Year-over-Year Growth Rate by Genre:")
print(sales_by_year_genre)

# Visualize the growth rate
plt.figure(figsize=(14, 8))
sns.lineplot(data=sales_by_year_genre, x='year', y='growth_rate', hue='genre', marker='o')
plt.title('Year-over-Year Growth Rate by Genre')
plt.xlabel('Year')
plt.ylabel('Growth Rate (%)')
plt.xticks(rotation=45)
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Year-over-Year Growth Rate by Genre:
#        year         genre  global_sales  growth_rate
# 0    1980.0        Action          0.34          NaN
# 1    1980.0      Fighting          0.77          NaN
# 2    1980.0          Misc          2.70          NaN
# 3    1980.0       Shooter          7.07          NaN
# 4    1980.0        Sports          0.50          NaN
# ..      ...           ...           ...          ...
# 384  2016.0        Sports         14.63   -64.738491
# 385  2016.0      Strategy          0.52   -71.428571
# 386  2017.0        Action          0.01   -99.949622
# 387  2017.0  Role-Playing          0.04   -99.407407
# 388  2020.0    Simulation          0.29   -25.641026
#
# [389 rows x 4 columns]

# %% [markdown]
# # Exporting Dataframes to CSV/Excel

# %%
pip install xlsxwriter
#installing xlsxwriter to do this task
# Out:
# ...
#                                               0.0/159.9 kB ? eta -:--:--
#      -------------------------------------- 159.9/159.9 kB 9.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
total_sales_by_platform = df.groupby('platform')['global_sales'].sum()

sorted_total_sales_by_platform = total_sales_by_platform.sort_values(ascending=False)

df3 = sorted_total_sales_by_platform

# total_sales_by_platform df (NOT USED, INEFFECTIVE)

# %%
avg_sales_by_genre = df.groupby('genre')['global_sales'].mean()

sorted_avg_sales_by_genre = avg_sales_by_genre.sort_values(ascending=False)

df2 = sorted_avg_sales_by_genre.reset_index()

#avg_sales_by_platform df (USED)

# %%
sum_sales_by_platform_year = df.groupby(['platform', 'year'])['global_sales'].sum().reset_index()

sorted_sum_sales_by_platform_year = sum_sales_by_platform_year.sort_values(by='global_sales',ascending=False)

df4 = sorted_sum_sales_by_platform_year

#sum_of_sales_by_platform_year df (USED)

# %%
sales_by_year = df.groupby('year')['global_sales'].sum()
sorted_sales_by_year = sales_by_year.sort_values(ascending=False)

df5 = sorted_sales_by_year.reset_index()

#sales_by_the_year df (USED)

# %%
#sales_distribution_by_publisher = df.groupby('publisher')['global_sales'].sum()

#total_sales = sales_distribution_by_publisher.sum()
#threshold = 0.05  # Top 5% of total sales
#min_sales = total_sales * threshold

#top_publishers = sales_distribution_by_publisher[sales_distribution_by_publisher >= min_sales]
#other_publishers = sales_distribution_by_publisher[sales_distribution_by_publisher < min_sales]

#top_publishers = top_publishers.append(pd.Series({'Other (a collective of many publishers)': other_publishers.sum()}))

#df6 = top_publishers.reset_index()
#df6.columns = ['Publisher', 'Total Sales']

#Distribution_of_sales_among_publishers df (NOT USED, INEFFECTIVE)
# Out:
# C:\Users\Khada Jhin\AppData\Local\Temp\ipykernel_27580\2865268799.py:10: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_publishers = top_publishers.append(pd.Series({'Other (a collective of many publishers)': other_publishers.sum()}))

# %%
genre_trends = df.groupby(['year', 'genre']).size().unstack().fillna(0)


df7 = genre_trends = genre_trends.reset_index()

#genre_trends df (USED)

# %%
#sales_summary = df['global_sales'].describe()

#Q1 = sales_summary['25%']
#Q3 = sales_summary['75%']
#IQR = Q3 - Q1

#outliers = df[df['global_sales'] > (Q3 + 1.5 * IQR)]

#df8 = outliers.copy()
#df8['Q1'] = Q1
#df8['Q3'] = Q3
#df8['IQR'] = IQR
#df8['Threshold'] = Q3 + 1.5 * IQR

#outliers df (NOT USED)

# %%
#genre_sales_by_region = df.groupby('genre')[['na_sales', 'eu_sales', 'jp_sales', 'global_sales']].sum()


#most_popular_genre_na = genre_sales_by_region['na_sales'].idxmax()
#most_popular_genre_eu = genre_sales_by_region['eu_sales'].idxmax()
#most_popular_genre_jp = genre_sales_by_region['jp_sales'].idxmax()
#most_popular_genre_global = genre_sales_by_region['global_sales'].idxmax()

#df9 = pd.DataFrame({
#    'Region': ['NA', 'EU', 'JP', 'Global'],
#    'Most Popular Genre': [
#        most_popular_genre_na,
#        most_popular_genre_eu,
#        most_popular_genre_jp,
#        most_popular_genre_global
#    ]
#})

#Genre_sales_by_region df (NOT USED, INEFFECTIVE)

# %%
#df['global_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']

#publisher_sales = df.groupby('publisher')[['na_sales', 'eu_sales', 'jp_sales', 'global_sales']].sum()

#top_publishers_global = publisher_sales['global_sales'].nlargest(5)

#df10 = publisher_sales.loc[top_publishers_global.index]

#Top Publishers by Global Sales (NOT USED, INEFFECTIVE)

# %%
excel_file_path = r'C:\Users\Khada Jhin\Documents\ClownfishSoundTemp\video_game_analysis.xlsx'

with pd.ExcelWriter('video_game_analysis.xlsx', engine='xlsxwriter') as writer:
    df2.to_excel(writer, sheet_name='Avg Sales by Genre', index=False)
    df4.to_excel(writer, sheet_name='Sum Sales by Platform Year', index = False)
    df5.to_excel(writer, sheet_name='Sales by the Year', index= False)
    df6.to_excel(writer, sheet_name='Distribution Publishers', index = False)
    df7.to_excel(writer, sheet_name='Genre trends', index = False)
    writer.save()

    

print(f"Excel file exported to {excel_file_path}")
# Out:
# Excel file exported to C:\Users\Khada Jhin\Documents\ClownfishSoundTemp\video_game_analysis.xlsx
# C:\Users\Khada Jhin\AppData\Local\Temp\ipykernel_27580\2273946272.py:13: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
# C:\Users\Khada Jhin\anaconda3\Lib\site-packages\xlsxwriter\workbook.py:369: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %% [markdown]
# # The Dataframes that are not listed in the above cell were not outputted correctly into excel due to their complex natures. For that, I will only be keeping the ones that were useful. The rest I will have to screenshot an image of the visualization here in Python and then somehow show it in Tableau.

# %%
# -- END OF ANALYSIS
